# %%
#디렉토리 구조 잡기
import os

BASE_DIR = "mp_survey"
DATA_DIR = os.path.join(BASE_DIR, "data")
META_DIR = os.path.join(BASE_DIR, "meta")
PROC_DIR = os.path.join(BASE_DIR, "processed")
USER_DIR = os.path.join(BASE_DIR, "users")
GROUP_DIR = os.path.join(BASE_DIR, "group")

for d in [BASE_DIR, DATA_DIR, META_DIR, PROC_DIR, USER_DIR, GROUP_DIR]:
    os.makedirs(d, exist_ok=True)

print(os.listdir(BASE_DIR))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2914813818.py in <cell line: 0>()
#       2
#       3 BASE_DIR = "mp_survey"
# ----> 4 DATA_DIR = os.path.join(BASE_DIR, "data")
#       5 META_DIR = os.path.join(BASE_DIR, "meta")
#       6 PROC_DIR = os.path.join(BASE_DIR, "processed")
#
# NameError: name 'os' is not defined
